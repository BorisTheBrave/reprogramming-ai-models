# %% [markdown]
# # Pandas data manipulation (not used currently)

# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('ous_data/data_preprocessed.csv')

# %%
df.shape
# Out:
# (27590, 41)

# %%
df.columns
# Out:
# Index(['IB3', 'IH1', 'IB2', 'IH2', 'IB1', 'IH3', 'IB4', 'IH4', 'IB5',
#        'confusion', 'careless_1', 'careless_2', 'careless_3',
#        'technical_problems', 'native_language', 'Q_Lang', 'religion_text',
#        'religion_1', 'religion_2', 'religion_3', 'religion_4', 'religion_5',
#        'religion_6', 'religion_7', 'religion_8', 'religion_9', 'religion_10',
#        'religion_11', 'religion_12', 'religion_13', 'religion_14',
#        'religion_15', 'religion_16', 'education_leve', 'education_level_iran',
#        'education_level_germ', 'age_1', 'sex', 'countr_origin_1', 'country3',
#        'Age'],
#       dtype='object')

# %%
Q_LANG = ["EN", "ZH-S", "FR", "DE", "EL", "HU", "IT", "PL", "PT", "RO", "RU", "SK", "TR", "ES-ARG ", "CHI ", "COL-ESP ", "ES-EC ", "ESP-ESP ", "ES-MX ", "ES-PE ", "ESP-SAL ", "ES-ES", "SERB"]

# %%
SPANISH = { "ES-ARG": "ES",
"CHI": "ES",
"COL-ESP": "ES",
"ES-EC": "ES",
"ESP-ESP": "ES",
"ES-MX": "ES",
"ES-PE": "ES",
"ESP-SAL": "ES",
"ES-ES": "ES" }

# %%
df1 = df.query('careless_1 == 2 and careless_2 == 2 and careless_3 == 1 and technical_problems == 1 and native_language == 1 and confusion < 3')

# %%
df1.shape
# Out:
# (20579, 41)

# %%
df1.columns
# Out:
# Index(['IB3', 'IH1', 'IB2', 'IH2', 'IB1', 'IH3', 'IB4', 'IH4', 'IB5',
#        'confusion', 'careless_1', 'careless_2', 'careless_3',
#        'technical_problems', 'native_language', 'Q_Lang', 'religion_text',
#        'religion_1', 'religion_2', 'religion_3', 'religion_4', 'religion_5',
#        'religion_6', 'religion_7', 'religion_8', 'religion_9', 'religion_10',
#        'religion_11', 'religion_12', 'religion_13', 'religion_14',
#        'religion_15', 'religion_16', 'education_leve', 'education_level_iran',
#        'education_level_germ', 'age_1', 'sex', 'countr_origin_1', 'country3',
#        'Age'],
#       dtype='object')

# %%
df2 = df1.query('Q_Lang in @Q_LANG')

# %%
df2['Q_Lang']
# Out:
# 0        EN
# 2        EN
# 4        EN
# 7        EN
# 9        EN
#          ..
# 27583    EL
# 27584    RU
# 27585    EN
# 27586    EN
# 27589    RU
# Name: Q_Lang, Length: 17139, dtype: object

# %%
df2.shape
# Out:
# (17139, 41)

# %%
df2.head(50)
# Out:
#     IB3  IH1  IB2  IH2  IB1  IH3  IB4  IH4  IB5  confusion  careless_1  \
# 0     2    1    3    2    6    2    2    1    4          1           2
# 2     4    3    2    5    4    5    1    2    3          1           2
# 4     3    5    5    6    4    5    2    4    5          1           2
# 7     6    2    5    2    5    2    2    1    2          1           2
# 9     3    2    3    4    6    4    5    5    2          2           2
# 11    6    2    5    3    5    2    7    2    7          1           2
# 12    2    2    7    5    6    6    7    3    7          1           2
# 13    5    5    6    2    7    4    6    2    6          2           2
# 14    4    2    3    1    4    3    5    2    4          1           2
# 15    5    7    2    6    3    7    4    7    1          2           2
# 16    3    5    5    5    2    5    3    6    6          1           2
# 18    4    3    5    5    4    3    5    4    3          1           2
# 19    4    4    5    5    5    4    5    4    2          2           2
# 22    6    6    4    7    3    7    6    7    4          2           2
# 24    5    4    2    3    2    4    2    2    2          1           2
# 26    3    2    4    3    3    6    4    3    2          1           2
# 27    5    5    2    5    3    7    3    5    2          2           2
# 28    1    1    1    1    1    7    1    1    1          1           2
# 29    5    5    5    5    3    2    2    4    3          1           2
# 31    6    3    2    3    6    2    2    2    2          2           2
# 32    6    2    5    4    3    5    3    5    4          1           2
# 34    4    4    4    6    2    5    3    4    3          1           2
# 35    5    1    6    1    7    4    6    1    1          1           2
# 40    3    2    5    3    6    3    3    1    2          1           2
# 41    3    1    6    5    7    6    2    3    6          2           2
# 43    6    3    2    6    3    5    5    5    2          2           2
# 44    5    1    4    1    7    1    2    1    4          1           2
# 45    1    1    1    1    1    1    1    7    7          1           2
# 46    6    2    6    2    6    2    6    2    2          2           2
# 47    7    6    7    7    6    7    5    6    7          2           2
# 48    5    5    6    6    6    2    4    4    6          2           2
# 49    3    2    2    2    4    6    1    5    4          1           2
# 50    4    1    6    6    3    7    2    2    2          1           2
# 51    1    7    1    1    7    7    1    1    1          1           2
# 52    1    1    1    1    7    1    1    1    1          1           2
# 55    2    1    5    4    7    2    5    4    6          1           2
# 57    1    5    2    4    2    1    2    4    3          2           2
# 58    4    5    5    3    4    6    4    6    5          2           2
# 59    4    1    1    5    6    4    2    2    2          1           2
# 60    2    2    3    6    6    2    6    2    2          2           2
# 61    5    2    6    5    5    3    2    2    5          1           2
# 63    4    6    4    4    7    4    5    5    5          2           2
# 64    3    1    6    4    3    4    2    1    5          1           2
# 66    1    2    1    1    1    5    2    2    1          1           2
# 67    1    1    1    7    3    6    6    5    1          1           2
# 68    5    1    6    4    5    6    2    4    4          1           2
# 69    4    2    1    5    2    4    1    3    5          2           2
# 72    5    1    4    5    5    3    6    3    3          2           2
# 73    2    3    7    5    3    1    5    3    5          2           2
# 74    7    4    4    7    7    5    6    4    4          1           2
#
#     careless_2  careless_3  technical_problems  native_language Q_Lang  \
# 0            2           1                 1.0              1.0     EN
# 2            2           1                 1.0              1.0     EN
# 4            2           1                 1.0              1.0     EN
# 7            2           1                 1.0              1.0     EN
# 9            2           1                 1.0              1.0     EN
# 11           2           1                 1.0              1.0     EN
# 12           2           1                 1.0              1.0     EN
# 13           2           1                 1.0              1.0     EN
# 14           2           1                 1.0              1.0     EN
# 15           2           1                 1.0              1.0     EN
# 16           2           1                 1.0              1.0     EN
# 18           2           1                 1.0              1.0     EN
# 19           2           1                 1.0              1.0     EN
# 22           2           1                 1.0              1.0   ZH-S
# 24           2           1                 1.0              1.0   ZH-S
# 26           2           1                 1.0              1.0   ZH-S
# 27           2           1                 1.0              1.0   ZH-S
# 28           2           1                 1.0              1.0   ZH-S
# 29           2           1                 1.0              1.0     EN
# 31           2           1                 1.0              1.0   ZH-S
# 32           2           1                 1.0              1.0     EN
# 34           2           1                 1.0              1.0   ZH-S
# 35           2           1                 1.0              1.0     EN
# 40           2           1                 1.0              1.0   ZH-S
# 41           2           1                 1.0              1.0     EN
# 43           2           1                 1.0              1.0     EN
# 44           2           1                 1.0              1.0     EN
# 45           2           1                 1.0              1.0     EN
# 46           2           1                 1.0              1.0     EN
# 47           2           1                 1.0              1.0     EN
# 48           2           1                 1.0              1.0     EN
# 49           2           1                 1.0              1.0   ZH-S
# 50           2           1                 1.0              1.0     EN
# 51           2           1                 1.0              1.0   ZH-S
# 52           2           1                 1.0              1.0   ZH-S
# 55           2           1                 1.0              1.0     EN
# 57           2           1                 1.0              1.0     EN
# 58           2           1                 1.0              1.0     EN
# 59           2           1                 1.0              1.0   ZH-S
# 60           2           1                 1.0              1.0   ZH-S
# 61           2           1                 1.0              1.0     EN
# 63           2           1                 1.0              1.0     EN
# 64           2           1                 1.0              1.0     EN
# 66           2           1                 1.0              1.0     EN
# 67           2           1                 1.0              1.0   ZH-S
# 68           2           1                 1.0              1.0     EN
# 69           2           1                 1.0              1.0     EN
# 72           2           1                 1.0              1.0     EN
# 73           2           1                 1.0              1.0     EN
# 74           2           1                 1.0              1.0   ZH-S
#
#    religion_text religion_1 religion_2 religion_3 religion_4 religion_5  \
# 0             --        NaN        NaN        NaN        NaN        NaN
# 2             --        NaN        NaN        NaN         --        NaN
# 4          --/--        NaN        NaN        NaN         --         --
# 7             --        NaN        NaN        NaN        NaN        NaN
# 9             --        NaN        NaN        NaN         --        NaN
# 11            --        NaN        NaN        NaN        NaN        NaN
# 12            --        NaN        NaN        NaN        NaN        NaN
# 13            --        NaN        NaN        NaN        NaN        NaN
# 14            --        NaN        NaN        NaN        NaN        NaN
# 15            --        NaN        NaN        NaN        NaN        NaN
# 16            --         --        NaN        NaN        NaN        NaN
# 18            --        NaN        NaN        NaN        NaN        NaN
# 19            --        NaN        NaN        NaN        NaN        NaN
# 22         --/--         --         --        NaN        NaN        NaN
# 24            --        NaN         --        NaN        NaN        NaN
# 26         --/--        NaN         --        NaN        NaN         --
# 27            --        NaN        NaN        NaN        NaN         --
# 28            --        NaN        NaN        NaN        NaN        NaN
# 29            --         --        NaN        NaN        NaN        NaN
# 31            --        NaN         --        NaN        NaN        NaN
# 32            --        NaN        NaN        NaN        NaN        NaN
# 34            --        NaN         --        NaN        NaN        NaN
# 35         --/--         --        NaN        NaN        NaN        NaN
# 40         --/--        NaN        NaN        NaN        NaN         --
# 41            --         --        NaN        NaN        NaN        NaN
# 43            --        NaN        NaN        NaN        NaN        NaN
# 44            --        NaN        NaN        NaN        NaN        NaN
# 45            --        NaN         --        NaN        NaN        NaN
# 46            --         --        NaN        NaN        NaN        NaN
# 47            --        NaN        NaN        NaN        NaN        NaN
# 48            --         --        NaN        NaN        NaN        NaN
# 49         --/--        NaN         --        NaN        NaN        NaN
# 50            --        NaN         --        NaN        NaN        NaN
# 51            --        NaN         --        NaN        NaN        NaN
# 52      --/--/--         --         --        NaN        NaN        NaN
# 55            --        NaN        NaN        NaN        NaN        NaN
# 57            --        NaN        NaN        NaN        NaN        NaN
# 58            --        NaN        NaN        NaN        NaN        NaN
# 59            --        NaN         --        NaN        NaN        NaN
# 60            --        NaN         --        NaN        NaN        NaN
# 61            --         --        NaN        NaN        NaN        NaN
# 63         --/--         --        NaN        NaN        NaN        NaN
# 64            --         --        NaN        NaN        NaN        NaN
# 66            --        NaN        NaN        NaN        NaN        NaN
# 67            --        NaN        NaN        NaN        NaN        NaN
# 68            --        NaN        NaN        NaN        NaN        NaN
# 69            --        NaN        NaN        NaN        NaN        NaN
# 72            --        NaN        NaN        NaN        NaN        NaN
# 73            --         --        NaN        NaN        NaN        NaN
# 74            --        NaN        NaN        NaN        NaN        NaN
#
#    religion_6 religion_7 religion_8 religion_9 religion_10 religion_11  \
# 0         NaN        NaN        NaN        NaN         NaN         NaN
# 2         NaN        NaN        NaN        NaN         NaN         NaN
# 4         NaN        NaN        NaN        NaN         NaN         NaN
# 7         NaN        NaN        NaN        NaN         NaN         NaN
# 9         NaN        NaN        NaN        NaN         NaN         NaN
# 11        NaN        NaN        NaN        NaN         NaN         NaN
# 12        NaN        NaN        NaN        NaN         NaN         NaN
# 13        NaN        NaN        NaN        NaN         NaN         NaN
# 14        NaN         --        NaN        NaN         NaN         NaN
# 15        NaN        NaN        NaN        NaN         NaN         NaN
# 16        NaN        NaN        NaN        NaN         NaN         NaN
# 18         --        NaN        NaN        NaN         NaN         NaN
# 19        NaN        NaN        NaN         --         NaN         NaN
# 22        NaN        NaN        NaN        NaN         NaN         NaN
# 24        NaN        NaN        NaN        NaN         NaN         NaN
# 26        NaN        NaN        NaN        NaN         NaN         NaN
# 27        NaN        NaN        NaN        NaN         NaN         NaN
# 28        NaN        NaN        NaN        NaN         NaN         NaN
# 29        NaN        NaN        NaN        NaN         NaN         NaN
# 31        NaN        NaN        NaN        NaN         NaN         NaN
# 32         --        NaN        NaN        NaN         NaN         NaN
# 34        NaN        NaN        NaN        NaN         NaN         NaN
# 35        NaN        NaN        NaN        NaN         NaN         NaN
# 40        NaN        NaN        NaN        NaN         NaN         NaN
# 41        NaN        NaN        NaN        NaN         NaN         NaN
# 43        NaN        NaN        NaN         --         NaN         NaN
# 44        NaN         --        NaN        NaN         NaN         NaN
# 45        NaN        NaN        NaN        NaN         NaN         NaN
# 46        NaN        NaN        NaN        NaN         NaN         NaN
# 47        NaN        NaN        NaN         --         NaN         NaN
# 48        NaN        NaN        NaN        NaN         NaN         NaN
# 49        NaN        NaN        NaN        NaN          --         NaN
# 50        NaN        NaN        NaN        NaN         NaN         NaN
# 51        NaN        NaN        NaN        NaN         NaN         NaN
# 52        NaN        NaN        NaN        NaN          --         NaN
# 55        NaN        NaN        NaN         --         NaN         NaN
# 57        NaN        NaN        NaN         --         NaN         NaN
# 58        NaN        NaN        NaN        NaN         NaN         NaN
# 59        NaN        NaN        NaN        NaN         NaN         NaN
# 60        NaN        NaN        NaN        NaN         NaN         NaN
# 61        NaN        NaN        NaN        NaN         NaN         NaN
# 63        NaN        NaN        NaN         --         NaN         NaN
# 64        NaN        NaN        NaN        NaN         NaN         NaN
# 66        NaN         --        NaN        NaN         NaN         NaN
# 67        NaN        NaN        NaN        NaN         NaN         NaN
# 68        NaN        NaN        NaN        NaN         NaN         NaN
# 69        NaN        NaN        NaN         --         NaN         NaN
# 72        NaN        NaN        NaN         --         NaN         NaN
# 73        NaN        NaN        NaN        NaN         NaN         NaN
# 74        NaN        NaN        NaN        NaN         NaN         NaN
#
#    religion_12 religion_13 religion_14 religion_15 religion_16  \
# 0           --         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 7           --         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN
# 11          --         NaN         NaN         NaN         NaN
# 12          --         NaN         NaN         NaN         NaN
# 13         NaN          --         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN
# 15          --         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN
# 28         NaN          --         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN         NaN
# 35         NaN         NaN          --         NaN         NaN
# 40         NaN         NaN          --         NaN         NaN
# 41         NaN         NaN         NaN         NaN         NaN
# 43         NaN         NaN         NaN         NaN         NaN
# 44         NaN         NaN         NaN         NaN         NaN
# 45         NaN         NaN         NaN         NaN         NaN
# 46         NaN         NaN         NaN         NaN         NaN
# 47         NaN         NaN         NaN         NaN         NaN
# 48         NaN         NaN         NaN         NaN         NaN
# 49         NaN         NaN         NaN         NaN         NaN
# 50         NaN         NaN         NaN         NaN         NaN
# 51         NaN         NaN         NaN         NaN         NaN
# 52         NaN         NaN         NaN         NaN         NaN
# 55         NaN         NaN         NaN         NaN         NaN
# 57         NaN         NaN         NaN         NaN         NaN
# 58          --         NaN         NaN         NaN         NaN
# 59         NaN         NaN         NaN         NaN         NaN
# 60         NaN         NaN         NaN         NaN         NaN
# 61         NaN         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN         NaN
# 67         NaN          --         NaN         NaN         NaN
# 68          --         NaN         NaN         NaN         NaN
# 69         NaN         NaN         NaN         NaN         NaN
# 72         NaN         NaN         NaN         NaN         NaN
# 73         NaN         NaN         NaN         NaN         NaN
# 74         NaN         NaN         NaN         NaN          --
#
#        education_leve  education_level_iran education_level_germ  age_1  \
# 0     Doctoral degree                   NaN                  NaN   18.0
# 2         High school                   NaN                  NaN    2.0
# 4         High school                   NaN                  NaN    2.0
# 7         High school                   NaN                  NaN    5.0
# 9         High school                   NaN                  NaN    3.0
# 11        High school                   NaN                  NaN    2.0
# 12        High school                   NaN                  NaN    2.0
# 13  Bachelor's degree                   NaN                  NaN    2.0
# 14  Bachelor's degree                   NaN                  NaN    5.0
# 15  Bachelor's degree                   NaN                  NaN    3.0
# 16  Bachelor's degree                   NaN                  NaN    1.0
# 18  Bachelor's degree                   NaN                  NaN    5.0
# 19  Bachelor's degree                   NaN                  NaN    7.0
# 22  Bachelor's degree                   NaN                  NaN    3.0
# 24  Bachelor's degree                   NaN                  NaN    5.0
# 26  Bachelor's degree                   NaN                  NaN    3.0
# 27        High school                   NaN                  NaN    2.0
# 28  Bachelor's degree                   NaN                  NaN    3.0
# 29    Master's degree                   NaN                  NaN   10.0
# 31  Bachelor's degree                   NaN                  NaN    3.0
# 32  Bachelor's degree                   NaN                  NaN   10.0
# 34  Bachelor's degree                   NaN                  NaN    5.0
# 35    Master's degree                   NaN                  NaN    6.0
# 40        High school                   NaN                  NaN    3.0
# 41  Bachelor's degree                   NaN                  NaN    8.0
# 43  Bachelor's degree                   NaN                  NaN    9.0
# 44  Bachelor's degree                   NaN                  NaN    8.0
# 45    Master's degree                   NaN                  NaN    7.0
# 46    Master's degree                   NaN                  NaN    8.0
# 47        High school                   NaN                  NaN    2.0
# 48    Master's degree                   NaN                  NaN    7.0
# 49  Bachelor's degree                   NaN                  NaN    3.0
# 50    Master's degree                   NaN                  NaN   10.0
# 51  Bachelor's degree                   NaN                  NaN    NaN
# 52  Bachelor's degree                   NaN                  NaN    3.0
# 55  Bachelor's degree                   NaN                  NaN    3.0
# 57  Bachelor's degree                   NaN                  NaN    7.0
# 58  Bachelor's degree                   NaN                  NaN    5.0
# 59        High school                   NaN                  NaN    3.0
# 60  Bachelor's degree                   NaN                  NaN    3.0
# 61  Bachelor's degree                   NaN                  NaN    1.0
# 63    Master's degree                   NaN                  NaN    9.0
# 64    Master's degree                   NaN                  NaN    8.0
# 66  Bachelor's degree                   NaN                  NaN    9.0
# 67  Bachelor's degree                   NaN                  NaN    3.0
# 68  Bachelor's degree                   NaN                  NaN    5.0
# 69  Bachelor's degree                   NaN                  NaN    8.0
# 72    Master's degree                   NaN                  NaN    5.0
# 73  Bachelor's degree                   NaN                  NaN    2.0
# 74  Bachelor's degree                   NaN                  NaN    5.0
#
#        sex  countr_origin_1 country3   Age
# 0     Male            226.0      ARE  35.0
# 2   Female            131.0      MYS  19.0
# 4   Female            131.0      MYS  19.0
# 7   Female            195.0      MYS  22.0
# 9   Female            131.0      MYS  20.0
# 11  Female            195.0      MYS  19.0
# 12  Female            100.0      MYS  19.0
# 13  Female            100.0      MYS  19.0
# 14  Female            131.0      MYS  22.0
# 15  Female            131.0      MYS  20.0
# 16    Male            131.0      MYS  18.0
# 18  Female            131.0      MYS  22.0
# 19  Female            131.0      MYS  24.0
# 22    Male             44.0      CHN  20.0
# 24    Male             44.0      CHN  22.0
# 26    Male             44.0      CHN  20.0
# 27    Male             44.0      CHN  19.0
# 28    Male             44.0      CHN  20.0
# 29    Male            100.0      IND  27.0
# 31  Female             44.0      CHN  20.0
# 32  Female            100.0      IND  27.0
# 34    Male             44.0      CHN  22.0
# 35    Male            100.0      IND  23.0
# 40    Male             44.0      CHN  20.0
# 41    Male            100.0      IND  25.0
# 43    Male            100.0      IND  26.0
# 44  Female            100.0      IND  25.0
# 45    Male            100.0      IND  24.0
# 46  Female            100.0      IND  25.0
# 47  Female            100.0      MYS  19.0
# 48    Male            100.0      IND  24.0
# 49    Male             44.0      CHN  20.0
# 50    Male            100.0      IND  27.0
# 51    Male              NaN      CHN   NaN
# 52    Male             44.0      CHN  20.0
# 55  Female            131.0      MYS  20.0
# 57  Female            100.0      IND  24.0
# 58  Female            131.0      MYS  22.0
# 59    Male             44.0      CHN  20.0
# 60    Male             44.0      CHN  20.0
# 61  Female            131.0      MYS  18.0
# 63    Male            100.0      IND  26.0
# 64    Male            100.0      IND  25.0
# 66    Male            100.0      IND  26.0
# 67    Male             44.0      CHN  20.0
# 68  Female            131.0      MYS  22.0
# 69    Male            100.0      IND  25.0
# 72  Female            100.0      IND  22.0
# 73  Female             64.0      MYS  19.0
# 74    Male             44.0      CHN  22.0

# %%
df2['Q_Lang'] = df2['Q_Lang'].map(lambda x: SPANISH.get(x) or x)
# Out:
# /var/folders/l8/kn3s865x1215_zj8rfdf3hv80000gn/T/ipykernel_16454/3691675781.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Q_Lang'] = df2['Q_Lang'].map(lambda x: SPANISH.get(x) or x)

# %%
df2['Q_Lang'] = df2['Q_Lang'].map(lambda x: SPANISH.get(x) if x in SPANISH else x)
# Out:
# /var/folders/l8/kn3s865x1215_zj8rfdf3hv80000gn/T/ipykernel_16454/1082569250.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Q_Lang'] = df2['Q_Lang'].map(lambda x: SPANISH.get(x) if x in SPANISH else x)

# %%
df2['Q_Lang'].isna().sum()
# Out:
# 0

# %%
ous_IB = df2[['IB1', 'IB2', 'IB3', 'IB4', 'IB5' , 'Q_Lang']]

# %%
ous_IB
# Out:
#        IB1  IB2  IB3  IB4  IB5 Q_Lang
# 0        6    3    2    2    4     EN
# 2        4    2    4    1    3     EN
# 4        4    5    3    2    5     EN
# 7        5    5    6    2    2     EN
# 9        6    3    3    5    2     EN
# ...    ...  ...  ...  ...  ...    ...
# 27583    5    6    3    1    6     EL
# 27584    1    1    6    1    2     RU
# 27585    1    1    5    2    1     EN
# 27586    2    4    3    2    5     EN
# 27589    3    2    2    4    2     RU
#
# [17139 rows x 6 columns]

# %%
ous_IH = df2[['IH1', 'IH2', 'IH3', 'IH4', 'Q_Lang']]

# %%
ous_IH
# Out:
#        IH1  IH2  IH3  IH4 Q_Lang
# 0        1    2    2    1     EN
# 2        3    5    5    2     EN
# 4        5    6    5    4     EN
# 7        2    2    2    1     EN
# 9        2    4    4    5     EN
# ...    ...  ...  ...  ...    ...
# 27583    3    3    5    5     EL
# 27584    1    6    2    5     RU
# 27585    6    1    5    5     EN
# 27586    5    5    4    3     EN
# 27589    3    5    5    3     RU
#
# [17139 rows x 5 columns]
